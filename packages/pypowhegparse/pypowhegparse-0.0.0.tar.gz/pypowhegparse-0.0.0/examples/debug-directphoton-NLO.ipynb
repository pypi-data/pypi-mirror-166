# %%
import pandas as pd
import pypowhegparse as ppp
pd.set_option('display.max_columns', None)
folder = "/home/apn/git/powheg-box-v2/directphoton/slurm/"

# %% [markdown]
# ## Checklimits

# %%
ppp.print_stats(folder)
ppp.print_warn_grep(folder,3)
# Out:
# #WARN    =  0
# #WWARN   =  0
# #WWWARN  =  0
# #WWWWARN =  0

# %% [markdown]
# ## Counters

# %%
#ddf = ppp.load_counter_folder(folder)
#ddf.xs("pwgcounters-st4").describe()

# %%
#ppp.multi_describe(ddf)#[["real time (sec)"]]

# %% [markdown]
# ## Stat

# %%
ddf = ppp.load_stat_folder(folder)
ddf.xs("pwg-st3-stat").describe()
# Out:
# proc   btilde pos.   weights:  btilde pos.   weights:+-stat  \
# count                1.000000                      1.000000
# mean            498412.590706                    814.770008
# std                       NaN                           NaN
# min             498412.590706                    814.770008
# 25%             498412.590706                    814.770008
# 50%             498412.590706                    814.770008
# 75%             498412.590706                    814.770008
# max             498412.590706                    814.770008
#
# proc   btilde |neg.| weights:  btilde |neg.| weights:+-stat  \
# count                     1.0                           1.0
# mean                      0.0                           0.0
# std                       NaN                           NaN
# min                       0.0                           0.0
# 25%                       0.0                           0.0
# 50%                       0.0                           0.0
# 75%                       0.0                           0.0
# max                       0.0                           0.0
#
# proc   btilde Total (pos.-|neg.|):  btilde Total (pos.-|neg.|):+-stat  \
# count                     1.000000                           1.000000
# mean                 498412.590706                         814.770008
# std                            NaN                                NaN
# min                  498412.590706                         814.770008
# 25%                  498412.590706                         814.770008
# 50%                  498412.590706                         814.770008
# 75%                  498412.590706                         814.770008
# max                  498412.590706                         814.770008
#
# proc   suppression factor in pb  suppression factor in pb+-stat  \
# count                  1.000000                        1.000000
# mean              498412.590706                      814.770008
# std                         NaN                             NaN
# min               498412.590706                      814.770008
# 25%               498412.590706                      814.770008
# 50%               498412.590706                      814.770008
# 75%               498412.590706                      814.770008
# max               498412.590706                      814.770008
#
# proc     negative weight fraction:
# count                          1.0
# mean                           0.0
# std                            NaN
# min                            0.0
# 25%                            0.0
# 50%                            0.0
# 75%                            0.0
# max                            0.0

# %%
ppp.multi_describe(ddf)
# Out:
# proc                btilde pos.   weights:  btilde pos.   weights:+-stat  \
# pwg-st2-stat count                1.000000                      1.000000
#              mean            498412.590706                    814.770008
#              std                       NaN                           NaN
#              min             498412.590706                    814.770008
#              25%             498412.590706                    814.770008
#              50%             498412.590706                    814.770008
#              75%             498412.590706                    814.770008
#              max             498412.590706                    814.770008
# pwg-st3-stat count                1.000000                      1.000000
#              mean            498412.590706                    814.770008
#              std                       NaN                           NaN
#              min             498412.590706                    814.770008
#              25%             498412.590706                    814.770008
#              50%             498412.590706                    814.770008
#              75%             498412.590706                    814.770008
#              max             498412.590706                    814.770008
# pwg-stat     count                1.000000                      1.000000
#              mean            498412.590706                    814.770008
#              std                       NaN                           NaN
#              min             498412.590706                    814.770008
#              25%             498412.590706                    814.770008
#              50%             498412.590706                    814.770008
#              75%             498412.590706                    814.770008
#              max             498412.590706                    814.770008
#
# proc                btilde |neg.| weights:  btilde |neg.| weights:+-stat  \
# pwg-st2-stat count                     1.0                           1.0
#              mean                      0.0                           0.0
#              std                       NaN                           NaN
#              min                       0.0                           0.0
#              25%                       0.0                           0.0
#              50%                       0.0                           0.0
#              75%                       0.0                           0.0
#              max                       0.0                           0.0
# pwg-st3-stat count                     1.0                           1.0
#              mean                      0.0                           0.0
#              std                       NaN                           NaN
#              min                       0.0                           0.0
#              25%                       0.0                           0.0
#              50%                       0.0                           0.0
#              75%                       0.0                           0.0
#              max                       0.0                           0.0
# pwg-stat     count                     1.0                           1.0
#              mean                      0.0                           0.0
#              std                       NaN                           NaN
#              min                       0.0                           0.0
#              25%                       0.0                           0.0
#              50%                       0.0                           0.0
#              75%                       0.0                           0.0
#              max                       0.0                           0.0
#
# proc                btilde Total (pos.-|neg.|):  \
# pwg-st2-stat count                     1.000000
#              mean                 498412.590706
#              std                            NaN
#              min                  498412.590706
#              25%                  498412.590706
#              50%                  498412.590706
#              75%                  498412.590706
#              max                  498412.590706
# pwg-st3-stat count                     1.000000
#              mean                 498412.590706
#              std                            NaN
#              min                  498412.590706
#              25%                  498412.590706
#              50%                  498412.590706
#              75%                  498412.590706
#              max                  498412.590706
# pwg-stat     count                     1.000000
#              mean                 498412.590706
#              std                            NaN
#              min                  498412.590706
#              25%                  498412.590706
#              50%                  498412.590706
#              75%                  498412.590706
#              max                  498412.590706
#
# proc                btilde Total (pos.-|neg.|):+-stat  \
# pwg-st2-stat count                           1.000000
#              mean                          814.770008
#              std                                  NaN
#              min                           814.770008
#              25%                           814.770008
#              50%                           814.770008
#              75%                           814.770008
#              max                           814.770008
# pwg-st3-stat count                           1.000000
#              mean                          814.770008
#              std                                  NaN
#              min                           814.770008
#              25%                           814.770008
#              50%                           814.770008
#              75%                           814.770008
#              max                           814.770008
# pwg-stat     count                           1.000000
#              mean                          814.770008
#              std                                  NaN
#              min                           814.770008
#              25%                           814.770008
#              50%                           814.770008
#              75%                           814.770008
#              max                           814.770008
#
# proc                suppression factor in pb  suppression factor in pb+-stat  \
# pwg-st2-stat count                  1.000000                        1.000000
#              mean              498412.590706                      814.770008
#              std                         NaN                             NaN
#              min               498412.590706                      814.770008
#              25%               498412.590706                      814.770008
#              50%               498412.590706                      814.770008
#              75%               498412.590706                      814.770008
#              max               498412.590706                      814.770008
# pwg-st3-stat count                  1.000000                        1.000000
#              mean              498412.590706                      814.770008
#              std                         NaN                             NaN
#              min               498412.590706                      814.770008
#              25%               498412.590706                      814.770008
#              50%               498412.590706                      814.770008
#              75%               498412.590706                      814.770008
#              max               498412.590706                      814.770008
# pwg-stat     count                  1.000000                        1.000000
#              mean              498412.590706                      814.770008
#              std                         NaN                             NaN
#              min               498412.590706                      814.770008
#              25%               498412.590706                      814.770008
#              50%               498412.590706                      814.770008
#              75%               498412.590706                      814.770008
#              max               498412.590706                      814.770008
#
# proc                  negative weight fraction:
# pwg-st2-stat count                          1.0
#              mean                           0.0
#              std                            NaN
#              min                            0.0
#              25%                            0.0
#              50%                            0.0
#              75%                            0.0
#              max                            0.0
# pwg-st3-stat count                          1.0
#              mean                           0.0
#              std                            NaN
#              min                            0.0
#              25%                            0.0
#              50%                            0.0
#              75%                            0.0
#              max                            0.0
# pwg-stat     count                          1.0
#              mean                           0.0
#              std                            NaN
#              min                            0.0
#              25%                            0.0
#              50%                            0.0
#              75%                            0.0
#              max                            0.0

# %% [markdown]
# ## Top

# %%
dddf = ppp.load_top_folder(folder)
dddf
# Out:
# title                              pvalue      chi2  \
# pwg-btlgrid 1 dim=           1   0.037198  4.341305
#               dim=           2   0.339446  0.912521
#               dim=           3   0.249621  1.325421
#               dim=           4   0.972637  0.001177
#               dim=           5   0.934829  0.006686
#               dim=           6   0.929204  0.007894
#
# title                                                                         plot
# pwg-btlgrid 1 dim=           1   <pytopdrawer.topplot.TopPlot object at 0x7fafd...
#               dim=           2   <pytopdrawer.topplot.TopPlot object at 0x7fafd...
#               dim=           3   <pytopdrawer.topplot.TopPlot object at 0x7fafd...
#               dim=           4   <pytopdrawer.topplot.TopPlot object at 0x7fafd...
#               dim=           5   <pytopdrawer.topplot.TopPlot object at 0x7fafd...
#               dim=           6   <pytopdrawer.topplot.TopPlot object at 0x7fafd...

# %%
for p in dddf.xs("pwg-btlgrid").xs(1)["plot"]:
    p.show(size=(5,5),fmt="-")
for p in dddf.xs("pwg-rmngrid").xs(1)["plot"]:
    p.show(size=(5,5),fmt="-")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# /usr/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'pwg-rmngrid'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_21965/4172305495.py in <module>
#       1 for p in dddf.xs("pwg-btlgrid").xs(1)["plot"]:
#       2     p.show(size=(5,5),fmt="-")
# ----> 3 for p in dddf.xs("pwg-rmngrid").xs(1)["plot"]:
#       4     p.show(size=(5,5),fmt="-")
#
# /usr/lib/python3.8/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3855
#    3856         if isinstance(index, MultiIndex):
# -> 3857             loc, new_index = index._get_loc_level(key, level=0)
#    3858             if not drop_level:
#    3859                 if lib.is_integer(loc):
#
# /usr/lib/python3.8/site-packages/pandas/core/indexes/multi.py in _get_loc_level(self, key, level)
#    3111                 return indexer, maybe_mi_droplevels(indexer, ilevels)
#    3112         else:
# -> 3113             indexer = self._get_level_indexer(key, level=level)
#    3114             if (
#    3115                 isinstance(key, str)
#
# /usr/lib/python3.8/site-packages/pandas/core/indexes/multi.py in _get_level_indexer(self, key, level, indexer)
#    3220         else:
#    3221
# -> 3222             idx = self._get_loc_single_level_index(level_index, key)
#    3223
#    3224             if level > 0 or self._lexsort_depth == 0:
#
# /usr/lib/python3.8/site-packages/pandas/core/indexes/multi.py in _get_loc_single_level_index(self, level_index, key)
#    2800             return -1
#    2801         else:
# -> 2802             return level_index.get_loc(key)
#    2803
#    2804     def get_loc(self, key, method=None):
#
# /usr/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
# -> 3623                 raise KeyError(key) from err
#    3624             except TypeError:
#    3625                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'pwg-rmngrid'

# %%
import numpy as np
from uncertainties import unumpy as unp
def fitr(x):
    return 1./(unp.exp(-10*(x-0.5))+1)
for p in [dddf.xs("pwg-btlgrid").xs(1)["plot"][0]]:
    p.fit(fitr,size=(5,5),fmt="-",logx=False,fselector=lambda x,y : np.logical_and(x>0,x>0) ,extrapolate=False)

# %%
for p in [dddf.xs("pwg-btlgrid").xs(1)["plot"][0]]:
    p.auto(size=(10,10),fmt="-",logx=True,fselector=lambda x,y : x>0,extrapolate=False)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 25.29it/s]
