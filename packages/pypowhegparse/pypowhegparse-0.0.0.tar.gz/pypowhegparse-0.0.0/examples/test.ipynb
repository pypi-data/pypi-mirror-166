# %% [markdown]
# ## Checklimits

# %%
import pypowhegparse as ppp

ppp.print_stats(".")

for s in ppp.inspect_warn_grep(".",2)[0]:
    print(s)
# Out:
# #WARN    =  456
# #WWARN   =  303
# #WWWARN  =  0
# #WWWWARN =  0
# b'./pwhg_checklimits-  Random radiation variables ====>   0.52053146956651020       0.10000000000000001       0.27124508007986847     '
# b'./pwhg_checklimits- ######### Check coll  0.10000000000000001     '
# b'./pwhg_checklimits- ######### Check coll   1.0000000000000000E-002'
# b'./pwhg_checklimits- ######### Check coll   1.0000000000000000E-003'
# b'./pwhg_checklimits- ######### Check coll   1.0000000000000000E-004'
# b'./pwhg_checklimits- ######### Check coll   1.0000000000000001E-005'
# b'./pwhg_checklimits- ######### Check coll   9.9999999999999995E-007'
# b'./pwhg_checklimits- ######### Check coll   9.9999999999999995E-008'
# b'./pwhg_checklimits- ######### Check coll   1.0000000000000000E-008'
# b'./pwhg_checklimits- coll  emitter  5, process   -5   0  11 -11  -5   0'
# b'./pwhg_checklimits: alr=          11   1.3293529094570582      *-WWARN-*      '
# ...

# %% [markdown]
# ## Counters

# %%
import pandas as pd
p1 =ppp.load_counter_file("pwgcounters-0001.dat")
p2 = ppp.load_counter_file("pwgcounters-st4-0002.dat")
#p1.join(p2)
#print(p1[1])
pp = p1.append(p2)
pp
# Out:
# /tmp/ipykernel_25995/2537858558.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pp = p1.append(p2)
# proc   setrandom time (sec)    negative pdf values   \
# 1                        9.0              5794963.0
# 2                        0.0              5867608.0
#
# proc   upper bound failure in inclusive cross section   \
# 1                                                 20.0
# 2                                                 31.0
#
# proc   vetoed calls in inclusive cross section   \
# 1                                      218274.0
# 2                                      233427.0
#
# proc   upper bound failures in generation of radiation    vetoed radiation   \
# 1                                                  38.0           1347065.0
# 2                                                  44.0           1336744.0
#
# ...

# %%
pp.describe()
# Out:
# /tmp/ipykernel_25995/2741591834.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pp = p1.append(p2)
# proc    setrandom time (sec)    negative pdf values   \
# count                2.000000           2.000000e+00
# mean                 4.500000           5.831286e+06
# std                  6.363961           5.136777e+04
# min                  0.000000           5.794963e+06
# 25%                  2.250000           5.813124e+06
# 50%                  4.500000           5.831286e+06
# 75%                  6.750000           5.849447e+06
# max                  9.000000           5.867608e+06
#
# proc    upper bound failure in inclusive cross section   \
# count                                          2.000000
# mean                                          25.500000
# std                                            7.778175
# min                                           20.000000
# ...

# %%
ddf = ppp.load_counter_folder(".")
for i in ddf.index.get_level_values(0).unique():
    print(ddf.xs(i).describe())
ddf
# Out:
# proc    setrandom time (sec)    negative pdf values   \
# count                     1.0                    1.0
# mean                      0.0              5867608.0
# std                       NaN                    NaN
# min                       0.0              5867608.0
# 25%                       0.0              5867608.0
# 50%                       0.0              5867608.0
# 75%                       0.0              5867608.0
# max                       0.0              5867608.0
#
# proc    upper bound failure in inclusive cross section   \
# count                                               1.0
# mean                                               31.0
# std                                                 NaN
# min                                                31.0
# 25%                                                31.0
# 50%                                                31.0
# 75%                                                31.0
# ...

# %%
ddf.xs('pwgcounters')
# Out:
# proc   setrandom time (sec)    negative pdf values   \
# 1                        9.0              5794963.0
# 2                       10.0              5794963.0
#
# proc   upper bound failure in inclusive cross section   \
# 1                                                 20.0
# 2                                                 20.0
#
# proc   vetoed calls in inclusive cross section   \
# 1                                      218274.0
# 2                                      218274.0
#
# proc   upper bound failures in generation of radiation    vetoed radiation   \
# 1                                                  38.0           1347065.0
# 2                                                  38.0           1347065.0
#
# proc   virt time (sec)    real time (sec)    btilde cross section used:   \
# 1                 6.845       31734.256006                    1301.23384
# 2                 6.845       31734.256006                    1301.23384
#
# ...

# %% [markdown]
# ## Stat

# %%
ddf = ppp.load_stat_folder(".")
ddf
# Out:
# proc        btilde pos.   weights:  btilde |neg.| weights:  \
# pwg-stat 1                 912+/-9                 384+/-5
#
# proc        btilde Total (pos.-|neg.|):   Remnant cross section in pb  \
# pwg-stat 1                     528+/-12                        98+/-8
#
# proc         total (btilde+remnants) cross section in pb  \
# pwg-stat 1                                      626+/-14
#
# proc         negative weight fraction:
# pwg-stat 1                    0.275566

# %% [markdown]
# ## Top

# %%
dddf = ppp.load_top_folder(".")
dddf
# Out:
# /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/pypowhegparse/pypowhegparse/top.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pairs[number]=pairs[number].append(load_top_plot(top))
# /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/pypowhegparse/pypowhegparse/top.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pairs[number]=pairs[number].append(load_top_plot(top))
# /home/apn/data/de.neuwirthinformatik.Alexander/Development/git/pypowhegparse/pypowhegparse/top.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pairs[number]=pairs[number].append(load_top_plot(top))
# ...

# %%
dddf.xs("pwg-btlgrid").xs(2)["plot"][3].show(size=(5,5),fmt="-")
